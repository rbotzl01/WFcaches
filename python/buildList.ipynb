# %%
import requests
import json
import pandas as pd
from config import api_key

# %%
# New Dependency! Use this to pretty print the JSON
# https://docs.python.org/3/library/pprint.html
from pprint import pprint

# %%
# Note that the ?t= is a query param for the t-itle of the
# movie we want to search for.
base_url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key

# %%
movieList_path = "../data/WF_cacheList.csv"

# %%
movieList = pd.read_csv(movieList_path)

# %%
movieList
# Out:
#                                         Movie Title  \
# 0       Austin Powers: International Man of Mystery
# 1                            A Night at the Roxbury
# 2                                          Hercules
# 3             Austin Powers: The Spy Who Shagged Me
# 4                                              Dick
# 5                                         Superstar
# 6                                     Drowning Mona
# 7                                    The Ladies Man
# 8                                         Zoolander
# 9                                         Boat Trip
# 10                                       Old School
# 11                                              Elf
# 12                                  Starsky & Hutch
# 13            Anchorman: The Legend of Ron Burgundy
# 14                              Melinda and Melinda
# 15                          The Wendell Baker Story
# 16                              Kicking & Screaming
# 17                                        Bewitched
# 18                                 Wedding Crashers
# 19                                   Winter Passing
# 20                                    The Producers
# 21                                   Curious George
# 22      Talladega Nights: The Ballad of Ricky Bobby
# 23                            Stranger Than Fiction
# 24                                  Blades of Glory
# 25                                         Semi-Pro
# 26                                    Step Brothers
# 27                                 Land of the Lost
# 28                  The Goods: Live Hard, Sell Hard
# 29                                   The Other Guys
# 30                               Everything Must Go
# 31                                         Megamind
# 32                                     The Campaign
# 33                                   The Internship
# 34                Anchorman 2: The Legend Continues
# 35                                   The Lego Movie
# 36                                         Get Hard
# 37                                     Daddy's Home
# 38                                      Zoolander 2
# 39                                        The House
# 40                                   Daddy's Home 2
# 41                                  Holmes & Watson
# 42                The Lego Movie 2: The Second Part
# 43                                    Drunk Parents
# 44                                        Zeroville
# 45                     Between Two Ferns: The Movie
# 46                                         Downhill
# 47  Eurovision Song Contest: The Story of Fire Saga
#
#                             Character Name                         Cache Name  \
# 0                                  Mustafa                                NaN
# 1                             Steve Butabi                                NaN
# 2                                   Geryon                                NaN
# 3                                  Mustafa                                NaN
# 4                             Bob Woodward                                NaN
# 5                     Sky Corrigan / Jesus                                NaN
# 6                                    Cubby             "Paralyzed with Grief"
# 7                             Lance DeLune                                NaN
# 8                           Jacobim Mugatu                         Derelichte
# 9   Michael, Brad's Boyfriend (uncredited)                                NaN
# 10                            Frank Ricard                                NaN
# 11                                   Buddy                   "I'm SINGING!!!"
# 12                   Big Earl (uncredited)                                NaN
# 13                            Ron Burgundy                                NaN
# 14                                   Hobie                                NaN
# 15                                    Dave                                NaN
# 16                             Phil Weston         Buck Weston's Sports Store
# 17                              Jack Wyatt  "Guess what? I'm a Clippers fan!"
# 18             Chazz Reinhold (uncredited)                                NaN
# 19                                  Corbit                                NaN
# 20                          Franz Liebkind                                NaN
# 21           Ted - Man with the Yellow Hat                                NaN
# 22                             Ricky Bobby                                NaN
# 23                            Harold Crick                                NaN
# 24                  Chazz Michael Michaels                         Iron Lotus
# 25                             Jackie Moon                                NaN
# 26                            Brennan Huff                                NaN
# 27                       Dr. Rick Marshall                                NaN
# 28                  McDermott (uncredited)                                NaN
# 29                            Allen Gamble                                NaN
# 30                             Nick Halsey                                NaN
# 31                                Megamind           MeTROCity Shall Be Mine!
# 32                               Cam Brady                                NaN
# 33          Mattress Salesman (uncredited)                                NaN
# 34                            Ron Burgundy                                NaN
# 35                           Lord Business                                NaN
# 36                                   James                                NaN
# 37                           Brad Whitaker                                NaN
# 38                          Jacobim Mugatu                                NaN
# 39                          Scott Johansen                                NaN
# 40                           Brad Whitaker                                NaN
# 41                         Sherlock Holmes                                NaN
# 42                      President Business                                NaN
# 43                        Bum (uncredited)                                NaN
# 44                                 Rondell                                NaN
# 45                            Will Ferrell                                NaN
# 46                                    Pete                                NaN
# 47                         Lars Erickssong    "The Elves Have Gone Too Far!!"
#
#      Cache Type                                  Cache Description  \
# 0           NaN                                  cache page puzzle
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                              coin cache by stream?
# 7           NaN                                                NaN
# 8   Traditional                     pill bottle covered in garbage
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11  Traditional                                                NaN
# 12          NaN                                                NaN
# 13          NaN                                                NaN
# 14          NaN                                                NaN
# 15          NaN                                                NaN
# 16        Multi  Stage 1: vitamin bottle in parking lot; Stage ...
# 17  Traditional                                  bison in the pine
# 18          NaN                                                NaN
# 19          NaN                                                NaN
# 20          NaN                                                NaN
# 21          NaN                                                NaN
# 22          NaN                                                NaN
# 23          NaN                                                NaN
# 24  Traditional                               water bottle in tree
# 25          NaN                                                NaN
# 26          NaN                                                NaN
# 27          NaN                                                NaN
# 28          NaN                                                NaN
# 29          NaN                                                NaN
# 30          NaN                                                NaN
# 31          NaN                                                NaN
# 32          NaN                                                NaN
# 33          NaN                                                NaN
# 34          NaN                                                NaN
# 35          NaN                                                NaN
# 36          NaN                                                NaN
# 37          NaN                                                NaN
# 38          NaN                                                NaN
# 39          NaN                                                NaN
# 40          NaN                                                NaN
# 41          NaN                                                NaN
# 42          NaN                                                NaN
# 43          NaN                                                NaN
# 44          NaN                                                NaN
# 45          NaN                                                NaN
# 46          NaN                                                NaN
# 47  Traditional                    mini ammo can "stolen" by elves
#
#                                            Cache Hint  Release Date  Rating  \
# 0                                "Drat! Three Times?"           NaN     NaN
# 1                                                 NaN           NaN     NaN
# 2                                                 NaN           NaN     NaN
# 3                                                 NaN           NaN     NaN
# 4                                                 NaN           NaN     NaN
# 5                                                 NaN           NaN     NaN
# 6   "I've seen more people more upset over losing ...           NaN     NaN
# 7                                                 NaN           NaN     NaN
# 8              "I feel like I am taking crazy pills!"           NaN     NaN
# 9                                                 NaN           NaN     NaN
# 10                                                NaN           NaN     NaN
# 11                                                NaN           NaN     NaN
# 12                                                NaN           NaN     NaN
# 13                                                NaN           NaN     NaN
# 14                                                NaN           NaN     NaN
# 15                                                NaN           NaN     NaN
# 16  Stage 2: "He's got balls!!; Stage 1": "And vit...           NaN     NaN
# 17                                                NaN           NaN     NaN
# 18                                                NaN           NaN     NaN
# 19                                                NaN           NaN     NaN
# 20                                                NaN           NaN     NaN
# 21                                                NaN           NaN     NaN
# 22                                                NaN           NaN     NaN
# 23                                                NaN           NaN     NaN
# 24                               it's "mind-bottling"           NaN     NaN
# 25                                                NaN           NaN     NaN
# 26                                                NaN           NaN     NaN
# 27                                                NaN           NaN     NaN
# 28                                                NaN           NaN     NaN
# 29                                                NaN           NaN     NaN
# 30                                                NaN           NaN     NaN
# 31                                                NaN           NaN     NaN
# 32                                                NaN           NaN     NaN
# 33                                                NaN           NaN     NaN
# 34                                                NaN           NaN     NaN
# 35                                                NaN           NaN     NaN
# 36                                                NaN           NaN     NaN
# 37                                                NaN           NaN     NaN
# 38                                                NaN           NaN     NaN
# 39                                                NaN           NaN     NaN
# 40                                                NaN           NaN     NaN
# 41                                                NaN           NaN     NaN
# 42                                                NaN           NaN     NaN
# 43                                                NaN           NaN     NaN
# 44                                                NaN           NaN     NaN
# 45                                                NaN           NaN     NaN
# 46                                                NaN           NaN     NaN
# 47  You may want to knock first; they have been kn...           NaN     NaN
#
#     Director  RT Rating
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8        NaN        NaN
# 9        NaN        NaN
# 10       NaN        NaN
# 11       NaN        NaN
# 12       NaN        NaN
# 13       NaN        NaN
# 14       NaN        NaN
# 15       NaN        NaN
# 16       NaN        NaN
# 17       NaN        NaN
# 18       NaN        NaN
# 19       NaN        NaN
# 20       NaN        NaN
# 21       NaN        NaN
# 22       NaN        NaN
# 23       NaN        NaN
# 24       NaN        NaN
# 25       NaN        NaN
# 26       NaN        NaN
# 27       NaN        NaN
# 28       NaN        NaN
# 29       NaN        NaN
# 30       NaN        NaN
# 31       NaN        NaN
# 32       NaN        NaN
# 33       NaN        NaN
# 34       NaN        NaN
# 35       NaN        NaN
# 36       NaN        NaN
# 37       NaN        NaN
# 38       NaN        NaN
# 39       NaN        NaN
# 40       NaN        NaN
# 41       NaN        NaN
# 42       NaN        NaN
# 43       NaN        NaN
# 44       NaN        NaN
# 45       NaN        NaN
# 46       NaN        NaN
# 47       NaN        NaN

# %%
# Performing a GET request similar to the one we executed
# earlier
for index, row in movieList.iterrows():
    cur_title = row['Movie Title']
    # Performing a GET request
    response = requests.get(base_url + cur_title + api_key)
    data = response.json()
    print(f"{data['Title']}")
    print(f"Movie was directed by {data['Director']}.")
    print(f"Movie was released in {data['Country']}.")
#response = requests.get(url + "" + api_key)
# Out:
# Austin Powers: International Man of Mystery
# Movie was directed by Jay Roach.
# Movie was released in United States.
# A Night at the Roxbury
# Movie was directed by John Fortenberry.
# Movie was released in United States.
# Hercules
# Movie was directed by Ron Clements, John Musker.
# Movie was released in United States.
# Austin Powers: The Spy Who Shagged Me
# Movie was directed by Jay Roach.
# Movie was released in United States.
# Dick
# Movie was directed by Andrew Fleming.
# Movie was released in United States, Canada, France.
# Superstar
# Movie was directed by Bruce McCulloch.
# Movie was released in United States.
# Drowning Mona
# Movie was directed by Nick Gomez.
# Movie was released in United States.
# The Ladies Man
# Movie was directed by Reginald Hudlin.
# Movie was released in United States.
# Zoolander
# Movie was directed by Ben Stiller.
# Movie was released in Germany, United States, Australia.
# Boat Trip
# Movie was directed by Mort Nathan.
# Movie was released in United States, Germany.
# Old School
# Movie was directed by Todd Phillips.
# Movie was released in United States.
# Elf
# Movie was directed by Jon Favreau.
# Movie was released in United States.
# Starsky & Hutch
# Movie was directed by Todd Phillips.
# Movie was released in United States.
# Anchorman: The Legend of Ron Burgundy
# Movie was directed by Adam McKay.
# Movie was released in United States.
# Melinda and Melinda
# Movie was directed by Woody Allen.
# Movie was released in United States.
# The Wendell Baker Story
# Movie was directed by Andrew Wilson, Luke Wilson.
# Movie was released in Germany, United States.
# Kicking & Screaming
# Movie was directed by Jesse Dylan.
# Movie was released in United States.
# Bewitched
# Movie was directed by Nora Ephron.
# Movie was released in United States.
# Wedding Crashers
# Movie was directed by David Dobkin.
# Movie was released in United States.
# Winter Passing
# Movie was directed by Adam Rapp.
# Movie was released in United States.
# The Producers
# Movie was directed by Mel Brooks.
# Movie was released in United States.
# Curious George
# Movie was directed by Matthew O'Callaghan.
# Movie was released in United States, Germany.
# Talladega Nights: The Ballad of Ricky Bobby
# Movie was directed by Adam McKay.
# Movie was released in United States.
# Stranger Than Fiction
# Movie was directed by Marc Forster.
# Movie was released in United States, United Kingdom.
# Blades of Glory
# Movie was directed by Josh Gordon, Will Speck.
# Movie was released in United States.
# Semi-Pro
# Movie was directed by Kent Alterman.
# Movie was released in United States.
# Step Brothers
# Movie was directed by Adam McKay.
# Movie was released in United States.
# Land of the Lost
# Movie was directed by Brad Silberling.
# Movie was released in United States.
# The Goods: Live Hard, Sell Hard
# Movie was directed by Neal Brennan.
# Movie was released in United States.
# The Other Guys
# Movie was directed by Adam McKay.
# Movie was released in United States.
# Everything Must Go
# Movie was directed by Dan Rush.
# Movie was released in United States.
# Megamind
# Movie was directed by Tom McGrath.
# Movie was released in United States.
# The Campaign
# Movie was directed by Jay Roach.
# Movie was released in United States.
# The Internship
# Movie was directed by Shawn Levy.
# Movie was released in United States.
# Anchorman 2: The Legend Continues
# Movie was directed by Adam McKay.
# Movie was released in United States.
# The Lego Movie
# Movie was directed by Christopher Miller, Phil Lord.
# Movie was released in United States, Denmark, Australia.
# Get Hard
# Movie was directed by Etan Cohen.
# Movie was released in United States.
# Daddy's Home
# Movie was directed by Sean Anders.
# Movie was released in United States.
# Zoolander 2
# Movie was directed by Ben Stiller.
# Movie was released in United States, Italy.
# The House
# Movie was directed by Andrew Jay Cohen.
# Movie was released in United States.
# Daddy's Home 2
# Movie was directed by Sean Anders.
# Movie was released in United States.
# Sherlock Holmes: A Game of Shadows
# Movie was directed by Guy Ritchie.
# Movie was released in United States, United Kingdom.
# The Lego Movie 2: The Second Part
# Movie was directed by Mike Mitchell.
# Movie was released in Denmark, Norway, Australia, United States.
# Drunk Parents
# Movie was directed by Fred Wolf.
# Movie was released in United States.
# Zeroville
# Movie was directed by James Franco.
# Movie was released in United States.
# Between Two Ferns: The Movie
# Movie was directed by Scott Aukerman.
# Movie was released in United States.
# Downhill
# Movie was directed by Nat Faxon, Jim Rash.
# Movie was released in United States.
# Eurovision Song Contest: The Story of Fire Saga
# Movie was directed by David Dobkin.
# Movie was released in United States, Iceland, Canada.

# %%
# Converting the response to JSON, and printing the result.
data = response.json()
pprint(data)
# Out:
# {'Error': 'Incorrect IMDb ID.', 'Response': 'False'}

# %%
# Print a few keys from the response JSON.
print(f"Movie was directed by {data['Director']}.")
print(f"Movie was released in {data['Country']}.")
# Out:
# Movie was directed by James Cameron.
# Movie was released in United Kingdom, United States.
